# %%
from main import DataPreprocessor
import seaborn as sns

df = sns.load_dataset("titanic")

p = DataPreprocessor(df)
df_clean = p.fit_transform(threshold=0.5, method="minmax")

print(df_clean.head())

print("Удалённые столбцы:")
print(p.dropped_columns)

print("Итоговые one-hot столбцы:")
print(p.ohe_columns)
# Out:
#    survived  pclass       age  sibsp  parch      fare  adult_male  alone  \
# 0       0.0     1.0  0.271174  0.125    0.0  0.014151        True  False
# 1       1.0     0.0  0.472229  0.125    0.0  0.139136       False  False
# 2       1.0     1.0  0.321438  0.000    0.0  0.015469       False   True
# 3       1.0     0.0  0.434531  0.125    0.0  0.103644       False  False
# 4       0.0     1.0  0.434531  0.000    0.0  0.015713        True   True
#
#    sex_female  sex_male  ...  class_Second  class_Third  who_child  who_man  \
# 0       False      True  ...         False         True      False     True
# 1        True     False  ...         False        False      False    False
# 2        True     False  ...         False         True      False    False
# 3        True     False  ...         False        False      False    False
# 4       False      True  ...         False         True      False     True
#
#    who_woman  embark_town_Cherbourg  embark_town_Queenstown  \
# ...
